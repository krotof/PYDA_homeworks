# %%
import pandas as pd

# %%
data = pd.read_csv('ratings.csv')
five_data = data[data['rating'] == 5]
five_data['movieId'].value_counts().head(5)
# Out:
# 318     153
# 296     123
# 356     116
# 2571    109
# 260     104
# Name: movieId, dtype: int64

# %%
power = pd.read_csv('power.csv')
filtered_power = power[(power['year'] >= 2005) & (power['year'] <= 2010) & ((power['country'] == 'Latvia') | (power['country'] == 'Lithuania') | (power['country'] == 'Estonia')) & ((power['category'] == 4) | (power['category'] == 12) | (power['category'] == 21)) & (power['quantity'] >= 0)]
filtered_power['quantity'].sum()
# Out:
# 240580.0

# %%
page_url = 'https://www.finanz.ru/valyuty/v-realnom-vremeni'
df = pd.read_html(page_url, attrs = {'class': 'quote_list'}, encoding='utf-8')
df[0]
# Out:
#     Unnamed: 0              Рубль  Предложение  Спрос  Предыдущее закрытие  \
# 0          NaN            GBP/RUB       939919      -               939872
# 1          NaN            EUR/RUB       827420      -               827100
# 2          NaN            USD/RUB       766030      -               764445
# 3          NaN            JPY/RUB        07061      -                07068
# 4          NaN            CNY/RUB       108037      -               108065
# 5          NaN            CHF/RUB       783960      -               784311
# 6          NaN               Евро  Предложение  Спрос  Предыдущее закрытие
# 7          NaN            EUR/USD        10804      -                10811
# 8          NaN            EUR/GBP        08807      -                08816
# 9          NaN            EUR/JPY      1172000      -              1172400
# 10         NaN            EUR/CHF        10557      -                10556
# ...
